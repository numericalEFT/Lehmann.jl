# %%
using Revise
using Plots
using Roots

# %%
include("../src/exact.jl")

# %%
freq = zeros(Float, 8)
freq[1] = 0.0
Q = [zeros(Float, 8), ]
Q[1][1] = 1.0 / Norm(freq[1])
# Out:
# 1.0

# %%
DNorm2(freq, Q, 0.01)
# Out:
# MethodError: no method matching DNorm2(::Vector{BigFloat}, ::Vector{Vector{BigFloat}}, ::Float64)
# Closest candidates are:
#   DNorm2(::Any, ::Any, ::BigFloat) at /Users/kunchen/project/Lehmann.jl/src/exact.jl:90
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
0.0025/0.008
# Out:
# 0.3125

# %%
ω = LinRange(1e-6, 0.1, 1000)
y = [Norm(freq, Q, w) for w in ω]
plot(ω, y, xlims=(0.0, 0.01), ylims=[0.0, 0.01])
# Out:
# MethodError: no method matching Norm(::Vector{BigFloat}, ::Vector{Vector{BigFloat}}, ::Float64)
# Closest candidates are:
#   Norm(::Any, ::Any, ::BigFloat) at /Users/kunchen/project/Lehmann.jl/src/exact.jl:66
#   Norm(::Any) at /Users/kunchen/project/Lehmann.jl/src/exact.jl:64
#
# Stacktrace:
#  [1] (::var"#9#10")(w::Float64)
#    @ Main ./none:0
#  [2] iterate
#    @ ./generator.jl:47 [inlined]
#  [3] collect(itr::Base.Generator{LinRange{Float64}, var"#9#10"})
#    @ Base ./array.jl:678
#  [4] top-level scope
#    @ In[7]:2
#  [5] eval
#    @ ./boot.jl:360 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
freq[2] = 1
push!(Q, orthognalize(freq, Q, freq[2]))
testOrthgonal(freq, Q)
# Out:
# Max Err: 1.7763568394002505e-15

# %%
DNorm2(freq, Q, 0.401)
# Out:
# 3.6052015414789196e-5

# %%
ω = LinRange(0.0, 4.0, 1000)
y = [Norm(freq, Q, w) for w in ω]
plot(ω, y, xlims=(0.0, 4.0), ylims=[0.0, 0.1])

# %%
freq[3] = 4
push!(Q, orthognalize(freq, Q, freq[3]))
testOrthgonal(freq, Q)
# Out:
# Max Err: 7.105427357601002e-15

# %%
ω = LinRange(0.0, 4.0, 1000)
y = [Norm(freq, Q, w) for w in ω]
plot(ω, y, xlims=(0.0, 4.0), ylims=[0.0, 0.1])

# %%
DNorm2(freq, Q, 0.001)
# Out:
# -1.996340031042859

# %%
q2=find_zero(x->DNorm2(freq, Q, x), (0.0+1e-10, 100.0), Bisection())
# Out:
# ArgumentError: The interval [a,b] is not a bracketing interval.
# You need f(a) and f(b) to have different signs (f(a) * f(b) < 0).
# Consider a different bracket or try fzero(f, c) with an initial guess c.
#
#
#
# Stacktrace:
#  [1] init_state(method::Bisection, fs::Roots.Callable_Function{Val{1}, Val{false}, var"#17#18", Nothing}, x::Tuple{Float64, Float64})
#    @ Roots ~/.julia/packages/Roots/RYBcg/src/bracketing.jl:78
#  [2] find_zero(fs::Function, x0::Tuple{Float64, Float64}, method::Bisection; p::Nothing, tracks::Roots.NullTracks, verbose::Bool, kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ Roots ~/.julia/packages/Roots/RYBcg/src/bracketing.jl:332
#  [3] find_zero(fs::Function, x0::Tuple{Float64, Float64}, method::Bisection)
#    @ Roots ~/.julia/packages/Roots/RYBcg/src/bracketing.jl:331
#  [4] top-level scope
#    @ In[21]:1
#  [5] eval
#    @ ./boot.jl:360 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
